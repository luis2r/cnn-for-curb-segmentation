# %%
import tensorflow as tf
import os.path
import warnings
from distutils.version import LooseVersion
import glob

import helper
import project_tests as tests

# %%
# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))
# Out:
# TensorFlow Version: 1.8.0

# %%
# Check for a GPU
if not tf.test.gpu_device_name():
  warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
  print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Default GPU Device: /device:GPU:0

# %%
DATA_DIRECTORY = '/home/shared/datasets'
RUNS_DIRECTORY = './runs'
TRAINING_DATA_DIRECTORY ='./data/data_road/training'
NUMBER_OF_IMAGES = len(glob.glob('./data/data_road/training/calib/*.*'))
VGG_PATH = './data/vgg'

# %%
NUMBER_OF_CLASSES = 2
IMAGE_SHAPE = (160, 576)

EPOCHS = 20
BATCH_SIZE = 1

LEARNING_RATE = 0.0001
DROPOUT = 0.75

# %%
correct_label = tf.placeholder(tf.float32, [None, IMAGE_SHAPE[0], IMAGE_SHAPE[1], NUMBER_OF_CLASSES])
learning_rate = tf.placeholder(tf.float32)
keep_prob = tf.placeholder(tf.float32)

# %%
# Used for plotting to visualize if our training is going well given parameters
all_training_losses = []

# %%
def load_vgg(sess, vgg_path):
  """
  Load Pretrained VGG Model into TensorFlow.
  sess: TensorFlow Session
  vgg_path: Path to vgg folder, containing "variables/" and "saved_model.pb"
  return: Tuple of Tensors from VGG model (image_input, keep_prob, layer3, layer4, layer7)
  """
  # load the model and weights
  model = tf.saved_model.loader.load(sess, ['vgg16'], vgg_path)

  # Get Tensors to be returned from graph
  graph = tf.get_default_graph()
  image_input = graph.get_tensor_by_name('image_input:0')
  keep_prob = graph.get_tensor_by_name('keep_prob:0')
  layer3 = graph.get_tensor_by_name('layer3_out:0')
  layer4 = graph.get_tensor_by_name('layer4_out:0')
  layer7 = graph.get_tensor_by_name('layer7_out:0')

  return image_input, keep_prob, layer3, layer4, layer7

# %%
def conv_1x1(layer, layer_name):
  """ Return the output of a 1x1 convolution of a layer """
  return tf.layers.conv2d(inputs = layer,
                          filters =  NUMBER_OF_CLASSES,
                          kernel_size = (1, 1),
                          strides = (1, 1),
                          name = layer_name)

# %%
def upsample(layer, k, s, layer_name):
  """ Return the output of transpose convolution given kernel_size k and strides s """
  # See: http://deeplearning.net/software/theano/tutorial/conv_arithmetic.html#transposed-convolution-arithmetic
  return tf.layers.conv2d_transpose(inputs = layer,
                                    filters = NUMBER_OF_CLASSES,
                                    kernel_size = (k, k),
                                    strides = (s, s),
                                    padding = 'same',
                                    name = layer_name)

# %%
def layers(vgg_layer3_out, vgg_layer4_out, vgg_layer7_out, num_classes = NUMBER_OF_CLASSES):
  """
  Create the layers for a fully convolutional network.  Build skip-layers using the vgg layers.
  vgg_layerX_out: TF Tensor for VGG Layer X output
  num_classes: Number of classes to classify
  return: The Tensor for the last layer of output
  """

  # Use a shorter variable name for simplicity
  layer3, layer4, layer7 = vgg_layer3_out, vgg_layer4_out, vgg_layer7_out

  # Apply a 1x1 convolution to encoder layers
  layer3x = conv_1x1(layer = layer3, layer_name = "layer3conv1x1")
  layer4x = conv_1x1(layer = layer4, layer_name = "layer4conv1x1")
  layer7x = conv_1x1(layer = layer7, layer_name = "layer7conv1x1")
 
  # Add decoder layers to the network with skip connections and upsampling
  # Note: the kernel size and strides are the same as the example in Udacity Lectures
  #       Semantic Segmentation Scene Understanding Lesson 10-9: FCN-8 - Decoder
  decoderlayer1 = upsample(layer = layer7x, k = 4, s = 2, layer_name = "decoderlayer1")
  decoderlayer2 = tf.add(decoderlayer1, layer4x, name = "decoderlayer2")
  decoderlayer3 = upsample(layer = decoderlayer2, k = 4, s = 2, layer_name = "decoderlayer3")
  decoderlayer4 = tf.add(decoderlayer3, layer3x, name = "decoderlayer4")
  decoderlayer_output = upsample(layer = decoderlayer4, k = 16, s = 8, layer_name = "decoderlayer_output")

  return decoderlayer_output

# %%
def layers_verbose(vgg_layer3_out, vgg_layer4_out, vgg_layer7_out, num_classes = NUMBER_OF_CLASSES):

  # Use a shorter variable name for simplicity
  layer3, layer4, layer7 = vgg_layer3_out, vgg_layer4_out, vgg_layer7_out

  # Apply a 1x1 convolution to encoder layers
  layer3x = conv_1x1(layer = layer3, layer_name = "layer3conv1x1")
  layer4x = conv_1x1(layer = layer4, layer_name = "layer4conv1x1")
  layer7x = conv_1x1(layer = layer7, layer_name = "layer7conv1x1")
 
  decoderlayer1 = upsample(layer = layer7x, k = 4, s = 2, layer_name = "decoderlayer1")
  decoderlayer2 = tf.add(decoderlayer1, layer4x, name = "decoderlayer2")
  decoderlayer3 = upsample(layer = decoderlayer2, k = 4, s = 2, layer_name = "decoderlayer3")
  decoderlayer4 = tf.add(decoderlayer3, layer3x, name = "decoderlayer4")
  decoderlayer_output = upsample(layer = decoderlayer4, k = 16, s = 8, layer_name = "decoderlayer_output")

  return layer3, layer4, layer7, layer3x, layer4x, layer7x, \
         decoderlayer1, decoderlayer2, decoderlayer3, decoderlayer4, decoderlayer_output

# %%
def optimize(nn_last_layer, correct_label, learning_rate, num_classes = NUMBER_OF_CLASSES):
  """
  Build the TensorFLow loss and optimizer operations.
  nn_last_layer: TF Tensor of the last layer in the neural network
  correct_label: TF Placeholder for the correct label image
  learning_rate: TF Placeholder for the learning rate
  num_classes: Number of classes to classify
  return: Tuple of (logits, train_op, cross_entropy_loss)
  """
  # reshape 4D tensors to 2D
  # Each row represents a pixel, each column a class
  logits = tf.reshape(nn_last_layer, (-1, num_classes))
  class_labels = tf.reshape(correct_label, (-1, num_classes))

  # The cross_entropy_loss is the cost which we are trying to minimize to yield higher accuracy
  cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = class_labels)
  cross_entropy_loss = tf.reduce_mean(cross_entropy)

  # The model implements this operation to find the weights/parameters that would yield correct pixel labels
  train_op = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy_loss)

  return logits, train_op, cross_entropy_loss

# %%
def train_nn(sess, epochs, batch_size, get_batches_fn, train_op,
             cross_entropy_loss, input_image,
             correct_label, keep_prob, learning_rate):
  """
  Train neural network and print out the loss during training.
  sess: TF Session
  epochs: Number of epochs
  batch_size: Batch size
  get_batches_fn: Function to get batches of training data.  Call using get_batches_fn(batch_size)
  train_op: TF Operation to train the neural network
  cross_entropy_loss: TF Tensor for the amount of loss
  input_image: TF Placeholder for input images
  correct_label: TF Placeholder for label images
  keep_prob: TF Placeholder for dropout keep probability
  learning_rate: TF Placeholder for learning rate
  """

  for epoch in range(EPOCHS):
    
    losses, i = [], 0
    
    for images, labels in get_batches_fn(BATCH_SIZE):
        
      i += 1
    
      feed = { input_image: images,
               correct_label: labels,
               keep_prob: DROPOUT,
               learning_rate: LEARNING_RATE }
        
      _, partial_loss = sess.run([train_op, cross_entropy_loss], feed_dict = feed)
      
      print("---> iteration: ", i, " partial loss:", partial_loss)
      losses.append(partial_loss)
          
    training_loss = sum(losses) / len(losses)
    all_training_losses.append(training_loss)
    
    print("------------------")
    print("epoch: ", epoch + 1, " of ", EPOCHS, "training loss: ", training_loss)
    print("------------------")

# %%
def run_tests():
  tests.test_layers(layers)
  tests.test_optimize(optimize)
  tests.test_for_kitti_dataset(DATA_DIRECTORY)
  tests.test_train_nn(train_nn)

# %%
def run():
  print("NUMBER OF IMAGES:", NUMBER_OF_IMAGES)

  # download vgg model
  helper.maybe_download_pretrained_vgg(DATA_DIRECTORY)

  # A function to get batches
  get_batches_fn = helper.gen_batch_function(TRAINING_DATA_DIRECTORY, IMAGE_SHAPE)
  
  with tf.Session() as session:
        
    # Returns the three layers, keep probability and input layer from the vgg architecture
    image_input, keep_prob, layer3, layer4, layer7 = load_vgg(session, VGG_PATH)

    # The resulting network architecture, adding a decoder on top of the given vgg model
    model_output = layers(layer3, layer4, layer7, NUMBER_OF_CLASSES)

    # Returns the output logits, training operation and cost operation to be used
    # For the logits: each row represents a pixel, each column a class
    # training operation is what is used to get the right parameters to the model to correctly label the pixels
    # the cross entropy loss is the cost which we are minimizing, lower cost should yield higher accuracy
    logits, train_op, cross_entropy_loss = optimize(model_output, correct_label, learning_rate, NUMBER_OF_CLASSES)
    
    # Initilize all variables
    session.run([tf.global_variables_initializer(), tf.local_variables_initializer()])

    # train the neural network
    train_nn(session, EPOCHS, BATCH_SIZE, get_batches_fn, 
             train_op, cross_entropy_loss, image_input,
             correct_label, keep_prob, learning_rate)

    # Save inference data
    helper.save_inference_samples(RUNS_DIRECTORY, DATA_DIRECTORY, session, IMAGE_SHAPE, logits, keep_prob, image_input)

# %%
import numpy as np 

def network_shapes():
  with tf.Session() as sess:
    
    x = np.random.randn(1, 160, 576, 3)
    
    image_input, keep_prob, layer3, layer4, layer7 = load_vgg(sess, VGG_PATH)
 
    op = layers_verbose(layer3, layer4, layer7, NUMBER_OF_CLASSES)
  
    sess.run([tf.global_variables_initializer(), tf.local_variables_initializer()])

    l3, l4, l7, l3x, l4x, l7x, d1, s2, d3, s4, d5 = sess.run(op, feed_dict = {image_input: x, keep_prob: 1.0})

    print("------------------")
    print("shapes of layers:") 
    print("------------------")

    print("layer3 -->", l3.shape)
    print("layer4 -->", l4.shape)
    print("layer7 -->", l7.shape)
    print("layer3 conv1x1 -->", l3x.shape)
    print("layer4 conv1x1 -->", l4x.shape)
    print("layer7 conv1x1-->", l7x.shape)
    print("decoderlayer1 transpose: layer7 k = 4 s = 2 -->", d1.shape)
    print("decoderlayer2 skip: decoderlayer1 and layer4conv1x1 -->", s2.shape)
    print("decoderlayer3 transpose: decoderlayer2 k = 4 s = 2 -->", d3.shape)
    print("decoderlayer4 skip: decoderlayer3 and layer3conv1x1 -->", s4.shape)
    print("decoderlayer5 transpose: decoderlayer4 k = 16 s = 8 -->", d5.shape)

# %% [markdown]
# # `network_shape()`
# - for the transpose layers **`s = stride`** and **`k = kernel/filter_size`**
# - running **`network_shape()`** will output the following:
#
#
# ```
# ------------------
# shapes of layers:
# ------------------
# layer3 --> (1, 20, 72, 256)
# layer4 --> (1, 10, 36, 512)
# layer7 --> (1, 5, 18, 4096)
# layer3 conv1x1 --> (1, 20, 72, 2)
# layer4 conv1x1 --> (1, 10, 36, 2)
# layer7 conv1x1--> (1, 5, 18, 2)
# decoderlayer1 transpose: layer7 k = 4 s = 2 --> (1, 10, 36, 2)
# decoderlayer2 skip: decoderlayer1 and layer4conv1x1 --> (1, 10, 36, 2)
# decoderlayer3 transpose: decoderlayer2 k = 4 s = 2 --> (1, 20, 72, 2)
# decoderlayer4 skip: decoderlayer3 and layer3conv1x1 --> (1, 20, 72, 2)
# decoderlayer5 transpose: decoderlayer4 k = 16 s = 8 --> (1, 160, 576, 2)
# ```

# %%
# Train the network
run()
# Out:
# NUMBER OF IMAGES: 289
# INFO:tensorflow:Restoring parameters from b'./data/vgg/variables/variables'
# ---> iteration:  1  partial loss: 52.9028
# ---> iteration:  2  partial loss: 62.7411
# ---> iteration:  3  partial loss: 39.6082
# ---> iteration:  4  partial loss: 34.8479
# ---> iteration:  5  partial loss: 23.9335
# ---> iteration:  6  partial loss: 32.3711
# ---> iteration:  7  partial loss: 21.1684
# ---> iteration:  8  partial loss: 20.0363
# ---> iteration:  9  partial loss: 16.3089
# ---> iteration:  10  partial loss: 14.2987
# ---> iteration:  11  partial loss: 14.5313
# ---> iteration:  12  partial loss: 14.4242
# ---> iteration:  13  partial loss: 11.2752
# ---> iteration:  14  partial loss: 9.47313
# ---> iteration:  15  partial loss: 8.47088
# ---> iteration:  16  partial loss: 10.6485
# ---> iteration:  17  partial loss: 7.36952
# ---> iteration:  18  partial loss: 8.68781
# ---> iteration:  19  partial loss: 8.06934
# ---> iteration:  20  partial loss: 5.35431
# ---> iteration:  21  partial loss: 5.41614
# ---> iteration:  22  partial loss: 4.45113
# ---> iteration:  23  partial loss: 4.10036
# ---> iteration:  24  partial loss: 3.52431
# ---> iteration:  25  partial loss: 4.66367
# ---> iteration:  26  partial loss: 3.07158
# ---> iteration:  27  partial loss: 2.78616
# ---> iteration:  28  partial loss: 2.5454
# ---> iteration:  29  partial loss: 2.75803
# ---> iteration:  30  partial loss: 2.98277
# ---> iteration:  31  partial loss: 3.43767
# ---> iteration:  32  partial loss: 2.85229
# ---> iteration:  33  partial loss: 2.17197
# ---> iteration:  34  partial loss: 2.32572
# ---> iteration:  35  partial loss: 2.31898
# ---> iteration:  36  partial loss: 2.1943
# ---> iteration:  37  partial loss: 2.43008
# ---> iteration:  38  partial loss: 1.96696
# ---> iteration:  39  partial loss: 1.84865
# ---> iteration:  40  partial loss: 1.54144
# ---> iteration:  41  partial loss: 2.0833
# ---> iteration:  42  partial loss: 1.98272
# ---> iteration:  43  partial loss: 1.60426
# ---> iteration:  44  partial loss: 1.80407
# ---> iteration:  45  partial loss: 1.91013
# ---> iteration:  46  partial loss: 1.90528
# ---> iteration:  47  partial loss: 1.44755
# ---> iteration:  48  partial loss: 2.07365
# ---> iteration:  49  partial loss: 1.65417
# ---> iteration:  50  partial loss: 1.41823
# ---> iteration:  51  partial loss: 1.69657
# ---> iteration:  52  partial loss: 1.83474
# ---> iteration:  53  partial loss: 1.31795
# ---> iteration:  54  partial loss: 1.7293
# ---> iteration:  55  partial loss: 1.27336
# ---> iteration:  56  partial loss: 1.49005
# ---> iteration:  57  partial loss: 1.21691
# ---> iteration:  58  partial loss: 1.52782
# ---> iteration:  59  partial loss: 1.23443
# ---> iteration:  60  partial loss: 1.28702
# ---> iteration:  61  partial loss: 1.30779
# ---> iteration:  62  partial loss: 1.30597
# ---> iteration:  63  partial loss: 1.15183
# ---> iteration:  64  partial loss: 1.34413
# ---> iteration:  65  partial loss: 1.35253
# ---> iteration:  66  partial loss: 1.27563
# ---> iteration:  67  partial loss: 1.12141
# ---> iteration:  68  partial loss: 1.34451
# ---> iteration:  69  partial loss: 1.35669
# ---> iteration:  70  partial loss: 1.30595
# ---> iteration:  71  partial loss: 1.12911
# ---> iteration:  72  partial loss: 1.04392
# ---> iteration:  73  partial loss: 1.10336
# ---> iteration:  74  partial loss: 1.20452
# ---> iteration:  75  partial loss: 1.05195
# ---> iteration:  76  partial loss: 1.19234
# ---> iteration:  77  partial loss: 1.22034
# ---> iteration:  78  partial loss: 1.30016
# ---> iteration:  79  partial loss: 0.93812
# ---> iteration:  80  partial loss: 1.36071
# ---> iteration:  81  partial loss: 1.03316
# ---> iteration:  82  partial loss: 1.17557
# ---> iteration:  83  partial loss: 1.23482
# ---> iteration:  84  partial loss: 0.988842
# ---> iteration:  85  partial loss: 0.985675
# ---> iteration:  86  partial loss: 1.01214
# ---> iteration:  87  partial loss: 1.03357
# ---> iteration:  88  partial loss: 1.08607
# ---> iteration:  89  partial loss: 0.920934
# ---> iteration:  90  partial loss: 1.01897
# ---> iteration:  91  partial loss: 1.08338
# ---> iteration:  92  partial loss: 1.29128
# ---> iteration:  93  partial loss: 1.10161
# ---> iteration:  94  partial loss: 1.0881
# ---> iteration:  95  partial loss: 0.900532
# ---> iteration:  96  partial loss: 0.981938
# ---> iteration:  97  partial loss: 0.897594
# ---> iteration:  98  partial loss: 1.03436
# ---> iteration:  99  partial loss: 1.09409
# ---> iteration:  100  partial loss: 0.938503
# ---> iteration:  101  partial loss: 0.958398
# ---> iteration:  102  partial loss: 1.12817
# ---> iteration:  103  partial loss: 1.13148
# ---> iteration:  104  partial loss: 0.925259
# ---> iteration:  105  partial loss: 0.928829
# ---> iteration:  106  partial loss: 1.162
# ---> iteration:  107  partial loss: 0.906437
# ---> iteration:  108  partial loss: 1.04893
# ---> iteration:  109  partial loss: 0.935642
# ---> iteration:  110  partial loss: 1.03213
# ---> iteration:  111  partial loss: 0.936488
# ---> iteration:  112  partial loss: 0.892886
# ---> iteration:  113  partial loss: 0.971352
# ---> iteration:  114  partial loss: 0.865933
# ---> iteration:  115  partial loss: 0.851419
# ---> iteration:  116  partial loss: 1.00072
# ---> iteration:  117  partial loss: 0.928294
# ---> iteration:  118  partial loss: 0.909615
# ---> iteration:  119  partial loss: 0.930079
# ---> iteration:  120  partial loss: 1.02059
# ---> iteration:  121  partial loss: 0.867238
# ---> iteration:  122  partial loss: 0.926494
# ---> iteration:  123  partial loss: 0.997099
# ---> iteration:  124  partial loss: 0.869626
# ---> iteration:  125  partial loss: 0.849276
# ---> iteration:  126  partial loss: 0.853009
# ---> iteration:  127  partial loss: 0.925403
# ---> iteration:  128  partial loss: 0.967108
# ---> iteration:  129  partial loss: 0.94421
# ---> iteration:  130  partial loss: 0.901579
# ---> iteration:  131  partial loss: 0.859228
# ---> iteration:  132  partial loss: 0.886903
# ---> iteration:  133  partial loss: 0.854482
# ---> iteration:  134  partial loss: 0.867697
# ---> iteration:  135  partial loss: 0.83973
# ---> iteration:  136  partial loss: 0.888368
# ---> iteration:  137  partial loss: 0.893853
# ---> iteration:  138  partial loss: 0.922442
# ---> iteration:  139  partial loss: 0.85304
# ---> iteration:  140  partial loss: 0.906351
# ---> iteration:  141  partial loss: 0.794298
# ---> iteration:  142  partial loss: 0.948639
# ---> iteration:  143  partial loss: 0.818612
# ---> iteration:  144  partial loss: 0.848539
# ---> iteration:  145  partial loss: 0.878299
# ---> iteration:  146  partial loss: 0.886879
# ---> iteration:  147  partial loss: 0.865529
# ---> iteration:  148  partial loss: 0.958545
# ---> iteration:  149  partial loss: 0.801978
# ---> iteration:  150  partial loss: 0.945239
# ---> iteration:  151  partial loss: 0.803321
# ---> iteration:  152  partial loss: 0.866985
# ---> iteration:  153  partial loss: 0.76282
# ---> iteration:  154  partial loss: 0.808566
# ---> iteration:  155  partial loss: 0.830875
# ---> iteration:  156  partial loss: 0.768059
# ---> iteration:  157  partial loss: 0.819421
# ---> iteration:  158  partial loss: 0.803383
# ---> iteration:  159  partial loss: 0.880169
# ---> iteration:  160  partial loss: 0.864349
# ---> iteration:  161  partial loss: 0.870698
# ---> iteration:  162  partial loss: 0.768867
# ---> iteration:  163  partial loss: 0.790333
# ---> iteration:  164  partial loss: 0.784486
# ---> iteration:  165  partial loss: 0.78942
# ---> iteration:  166  partial loss: 0.793082
# ---> iteration:  167  partial loss: 0.87267
# ---> iteration:  168  partial loss: 0.819384
# ---> iteration:  169  partial loss: 0.770936
# ---> iteration:  170  partial loss: 0.869347
# ---> iteration:  171  partial loss: 0.765812
# ---> iteration:  172  partial loss: 0.784582
# ---> iteration:  173  partial loss: 0.780666
# ---> iteration:  174  partial loss: 0.772895
# ---> iteration:  175  partial loss: 0.825972
# ---> iteration:  176  partial loss: 0.761339
# ---> iteration:  177  partial loss: 0.769907
# ---> iteration:  178  partial loss: 0.780288
# ---> iteration:  179  partial loss: 0.796764
# ---> iteration:  180  partial loss: 0.78935
# ---> iteration:  181  partial loss: 0.822347
# ---> iteration:  182  partial loss: 0.824116
# ---> iteration:  183  partial loss: 0.815293
# ---> iteration:  184  partial loss: 0.867558
# ---> iteration:  185  partial loss: 0.77762
# ---> iteration:  186  partial loss: 0.766723
# ---> iteration:  187  partial loss: 0.763533
# ---> iteration:  188  partial loss: 0.827284
# ---> iteration:  189  partial loss: 0.773155
# ---> iteration:  190  partial loss: 0.793659
# ---> iteration:  191  partial loss: 0.942875
# ---> iteration:  192  partial loss: 0.756409
# ---> iteration:  193  partial loss: 0.828444
# ---> iteration:  194  partial loss: 0.861918
# ---> iteration:  195  partial loss: 0.772875
# ---> iteration:  196  partial loss: 0.771679
# ---> iteration:  197  partial loss: 0.826511
# ---> iteration:  198  partial loss: 0.800985
# ---> iteration:  199  partial loss: 0.805592
# ---> iteration:  200  partial loss: 0.800596
# ---> iteration:  201  partial loss: 0.737586
# ---> iteration:  202  partial loss: 0.749786
# ---> iteration:  203  partial loss: 0.8069
# ---> iteration:  204  partial loss: 0.756279
# ---> iteration:  205  partial loss: 0.767447
# ---> iteration:  206  partial loss: 0.747562
# ---> iteration:  207  partial loss: 0.80861
# ---> iteration:  208  partial loss: 0.801355
# ---> iteration:  209  partial loss: 0.79072
# ---> iteration:  210  partial loss: 0.749729
# ---> iteration:  211  partial loss: 0.756291
# ---> iteration:  212  partial loss: 0.76123
# ---> iteration:  213  partial loss: 0.778629
# ---> iteration:  214  partial loss: 0.726546
# ---> iteration:  215  partial loss: 0.750438
# ---> iteration:  216  partial loss: 0.762979
# ---> iteration:  217  partial loss: 0.726796
# ---> iteration:  218  partial loss: 0.748677
# ---> iteration:  219  partial loss: 0.758062
# ---> iteration:  220  partial loss: 0.760302
# ---> iteration:  221  partial loss: 0.770843
# ---> iteration:  222  partial loss: 0.737796
# ---> iteration:  223  partial loss: 0.813173
# ---> iteration:  224  partial loss: 0.754671
# ---> iteration:  225  partial loss: 0.727378
# ---> iteration:  226  partial loss: 0.720799
# ---> iteration:  227  partial loss: 0.748032
# ---> iteration:  228  partial loss: 0.724494
# ---> iteration:  229  partial loss: 0.728015
# ---> iteration:  230  partial loss: 0.758444
# ---> iteration:  231  partial loss: 0.782389
# ---> iteration:  232  partial loss: 0.731101
# ---> iteration:  233  partial loss: 0.703679
# ---> iteration:  234  partial loss: 0.721328
# ---> iteration:  235  partial loss: 0.763822
# ---> iteration:  236  partial loss: 0.734299
# ---> iteration:  237  partial loss: 0.790014
# ---> iteration:  238  partial loss: 0.735779
# ---> iteration:  239  partial loss: 0.728776
# ---> iteration:  240  partial loss: 0.749751
# ---> iteration:  241  partial loss: 0.727072
# ---> iteration:  242  partial loss: 0.724679
# ---> iteration:  243  partial loss: 0.738966
# ---> iteration:  244  partial loss: 0.721703
# ---> iteration:  245  partial loss: 0.754173
# ---> iteration:  246  partial loss: 0.759251
# ---> iteration:  247  partial loss: 0.743987
# ---> iteration:  248  partial loss: 0.778372
# ---> iteration:  249  partial loss: 0.774094
# ---> iteration:  250  partial loss: 0.741035
# ---> iteration:  251  partial loss: 0.750697
# ---> iteration:  252  partial loss: 0.736078
# ---> iteration:  253  partial loss: 0.742566
# ---> iteration:  254  partial loss: 0.736314
# ---> iteration:  255  partial loss: 0.708326
# ---> iteration:  256  partial loss: 0.776048
# ---> iteration:  257  partial loss: 0.728976
# ---> iteration:  258  partial loss: 0.757866
# ---> iteration:  259  partial loss: 0.722703
# ---> iteration:  260  partial loss: 0.696263
# ---> iteration:  261  partial loss: 0.723184
# ---> iteration:  262  partial loss: 0.753486
# ---> iteration:  263  partial loss: 0.727727
# ---> iteration:  264  partial loss: 0.73435
# ---> iteration:  265  partial loss: 0.730133
# ---> iteration:  266  partial loss: 0.748233
# ---> iteration:  267  partial loss: 0.717365
# ---> iteration:  268  partial loss: 0.743236
# ---> iteration:  269  partial loss: 0.712144
# ---> iteration:  270  partial loss: 0.722467
# ---> iteration:  271  partial loss: 0.689302
# ---> iteration:  272  partial loss: 0.721374
# ---> iteration:  273  partial loss: 0.729067
# ---> iteration:  274  partial loss: 0.720121
# ---> iteration:  275  partial loss: 0.71896
# ---> iteration:  276  partial loss: 0.703651
# ---> iteration:  277  partial loss: 0.737576
# ---> iteration:  278  partial loss: 0.699223
# ---> iteration:  279  partial loss: 0.741278
# ---> iteration:  280  partial loss: 0.715775
# ---> iteration:  281  partial loss: 0.762998
# ---> iteration:  282  partial loss: 0.71485
# ---> iteration:  283  partial loss: 0.711214
# ---> iteration:  284  partial loss: 0.711369
# ---> iteration:  285  partial loss: 0.716536
# ---> iteration:  286  partial loss: 0.708915
# ---> iteration:  287  partial loss: 0.736509
# ---> iteration:  288  partial loss: 0.697142
# ---> iteration:  289  partial loss: 0.689841
# ------------------
# epoch:  1  of  1 training loss:  2.4432122002
# ------------------
# Training Finished. Saving test images to: ./runs/1503441936.1293008

# %%
all_training_losses
# Out:
# [2.4432122002010939]
